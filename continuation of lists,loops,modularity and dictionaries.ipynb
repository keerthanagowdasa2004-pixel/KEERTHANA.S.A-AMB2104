# %% [markdown]
# i=1
# while i<=10:
#     if i==4 or i==6:
#         i+=1
#         continue
#     print(i)
#     i+=1

# %%
num=1
while num!=0:
    num=int(input("enter a number:"))
    print(num)
# Out:
# enter a number: 3
# 3
# enter a number: 5
# 5
# enter a number: 9
# 9
# enter a number: 0
# 0

# %%
password=""
while password!="python":
    password=input("enter the password: ")
print("access granted")
# Out:
# enter the password:  Python
# enter the password:  python'
# enter the password:  python
# access granted

# %%
i=1
sum=0
while i<=5:
      sum=sum+i
      i+=1
print(sum)
# Out:
# 15

# %%
i=1
sum=0
while(sum<50):
     sum=sum+i
     i+=1
print(sum)
# Out:
# 55

# %%
S={'E','A','B','F','E','F'}
print("S",S)
print("type of object",type(S))
print("number of elements",len(S))
# Out:
# S {'E', 'A', 'B', 'F'}
# type of object <class 'set'>
# number of elements 4

# %% [markdown]
# transverse set elements

# %%
S={'E','A','B','F','E','F'}
print("S",S)
print("")
# Out:
# S {'E', 'A', 'B', 'F'}

# %%
S={'E','A','B','F','E','F'}
print("S",S)
for i in "S":
    print(i)
# Out:
# S {'E', 'A', 'B', 'F'}
# S

# %%
S={'E','A','B','F','E','F'}
for i in "S":
    print(i)
# Out:
# S

# %%
S={'E','A','B','F','E','F'}
print("S",S)
print(S[2])
# Out:
# S {'E', 'A', 'B', 'F'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 S={'E','A','B','F','E','F'}
#       2 print("S",S)
# ----> 3 print(S[2])
#
# TypeError: 'set' object is not subscriptable

# %%
S={'E','A','B','F','E','F'}
print("S",S)
S.add('D')
print("After adding 'D':",S)
# Out:
# S {'E', 'A', 'B', 'F'}
# After adding 'D': {'A', 'D', 'E', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
S2={'K','L','M','E','P','B'}
print("S1",S1)
print("S2",S2)
S1.update(S2)
print("after updating:",S1)
# Out:
# S1 {'E', 'A', 'B', 'F'}
# S2 {'K', 'P', 'E', 'L', 'M', 'B'}
# after updating: {'A', 'K', 'M', 'P', 'E', 'L', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
print('S',S)
S1.remove('A')
print("After removing 'A':",S1)
# Out:
# S {'A', 'D', 'E', 'B', 'F'}
# After removing 'A': {'E', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
print('S',S)
S1.discard('A')
print("After discarding 'A':",S1)
# Out:
# S {'A', 'D', 'E', 'B', 'F'}
# After discarding 'A': {'E', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
print('S',S)
S1.pop()
print("After popping:",S1)
# Out:
# S {'A', 'D', 'E', 'B', 'F'}
# After popping: {'A', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
print('S',S)
S1.clear()
print("after clearing the set:",S1)
# Out:
# S {'A', 'D', 'E', 'B', 'F'}
# after clearing the set: set()

# %%
S1={'E','A','B','F','E','F'}
print('S1',S1)
del(S1)
print("after deleting:",S1)
# Out:
# S1 {'E', 'A', 'B', 'F'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       2 print('S1',S1)
#       3 del(S1)
# ----> 4 print("after deleting:",S1)
#
# NameError: name 'S1' is not defined

# %%
S1={44,58,11,72,80,1}
print('S1',S1)
max(S1)
# Out:
# S1 {80, 1, 72, 58, 11, 44}
# 80

# %%
S1={44,58,11,72,80,1}
print('S1',S1)
min(S1)
# Out:
# S1 {80, 1, 72, 58, 11, 44}
# 1

# %%
S1={44,58,11,72,80,1}
print('S1',S1)
print("The sum of set S1 is:",sum(S1))
# Out:
# S1 {80, 1, 72, 58, 11, 44}
# The sum of set S1 is: 266

# %%
S1={'A','B','C'}
S2={'B','D','A'}
S1.difference(S2)
print('difference between S1 and S2 is:',S1.difference(S2))
# Out:
# difference between S1 and S2 is: {'C'}

# %%
S1={'E','A','B','F','E','F'}
S2={'K','L','M','E','P','B'}
print("S1",S1)
print("S2",S2)
S1.union(S2)
print("Union of S1 and S2 is :",S1.union(S2))
# Out:
# S1 {'E', 'A', 'B', 'F'}
# S2 {'K', 'P', 'E', 'L', 'M', 'B'}
# Union of S1 and S2 is : {'A', 'K', 'M', 'P', 'E', 'L', 'B', 'F'}

# %%
S1={'E','A','B','F','E','F'}
S2={'K','L','M','E','P','B'}
S1.intersection(S2)
print("S1 intersection S2:",S1.intersection(S2))
# Out:
# S1 intersection S2: {'E', 'B'}

# %%
S1={'E','A','B','F','E','F'}
S2={'K','L','M','E','P','B'}
S1.symmetric_difference(S2)
print("symmestric difference:",S1.symmetric_difference(S2))
# Out:
# symmestric difference: {'K', 'A', 'P', 'L', 'M', 'F'}

# %%
S1={'E','A','B','F','E','F'}
S2={'K','L','M','E','P','B'}
S1.difference(S2)
print(" difference:",S1.difference(S2))
# Out:
#  difference: {'A', 'F'}

# %%
S1={44,58,11,72,80,1}
print('S1',S1)
sum(S1)/len(S1)
print("average of S1 is :",sum(S1)/len(S1))
# Out:
# S1 {80, 1, 72, 58, 11, 44}
# average of S1 is : 44.333333333333336

# %% [markdown]
# Dictionary

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print("Dictionary:",cgpa)
print("total elements:",len(cgpa))
print("type of object:",type(cgpa))
print("cgpa of 1:",cgpa[1])
print("cgpa of 5:",cgpa[5])
# Out:
# Dictionary: {1: 8.9, 2: 5.2, 3: 8, 4: 9.1}
# total elements: 4
# type of object: <class 'dict'>
# cgpa of 1: 8.9
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 6
#       4 print("type of object:",type(cgpa))
#       5 print("cgpa of 1:",cgpa[1])
# ----> 6 print("cgpa of 5:",cgpa[5])
#
# KeyError: 5

# %% [markdown]
# TRAVERSE

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
for k in cgpa:
    print("cgpa of ",k,"-->\n",cgpa[k])
# Out:
# cgpa of  1 -->
#  8.9
# cgpa of  2 -->
#  5.2
# cgpa of  3 -->
#  8
# cgpa of  4 -->
#  9.1

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print("keys:",cgpa.keys())
print("values:",cgpa.values())
# Out:
# keys: dict_keys([1, 2, 3, 4])
# values: dict_values([8.9, 5.2, 8, 9.1])

# %%
cgpa={1:8.9,2:5.2,4:9.1}
cgpa[3]=8
print("after adding(3):",cgpa)
# Out:
# after adding(3): {1: 8.9, 2: 5.2, 4: 9.1, 3: 8}

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
cgpa[5]=9.1
print("after adding(5):",cgpa)
# Out:
# after adding(5): {1: 8.9, 2: 5.2, 3: 8, 4: 9.1, 5: 9.1}

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
del cgpa[3]
print("after deleting(3):",cgpa)
# Out:
# after deleting(3): {1: 8.9, 2: 5.2, 4: 9.1}

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
del cgpa
print("after deleting:",cgpa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 cgpa={1:8.9,2:5.2,3:8,4:9.1}
#       2 del cgpa
# ----> 3 print("after deleting:",cgpa)
#
# NameError: name 'cgpa' is not defined

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
cgpa.clear()
print("after clearing the dictionary:",cgpa)
# Out:
# after clearing the dictionary: {}

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
s=0
for i in cgpa:
    s=s+cgpa[i]
print("sum:",s)
print("average:",s/len(cgpa))
print("average:",s//len(cgpa))
# Out:
# sum: 31.200000000000003
# average: 7.800000000000001
# average: 7.0

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print("dictionary:",cgpa)
print("sum:",sum(cgpa.values()))
print("average:",sum(cgpa.values())/len(cgpa.values()))
print("average:",sum(cgpa.values())//len(cgpa.values()))
# Out:
# dictionary: {1: 8.9, 2: 5.2, 3: 8, 4: 9.1}
# sum: 31.2
# average: 7.8
# average: 7.0

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print("min:",min(cgpa.values()))
# Out:
# min: 5.2

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print("min:",min(cgpa.items()))
# Out:
# min: (1, 8.9)

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
print(cgpa.values())
print(cgpa.keys())
print(cgpa.items())
# Out:
# dict_values([8.9, 5.2, 8, 9.1])
# dict_keys([1, 2, 3, 4])
# dict_items([(1, 8.9), (2, 5.2), (3, 8), (4, 9.1)])

# %% [markdown]
# To find key for min value

# %%
keylist=list(cgpa.keys())
vallist=list(cgpa.values())
minval=min(cgpa.values())
print("\n value=",minval,"key:",keylist[vallist.index(minval)])
# Out:
#  value= 5.2 key: 2

# %%
print("key having min value:",min(cgpa,key=cgpa.get))
# Out:
# key having min value: 2

# %%
print("Is key 2 present:",2 in cgpa.keys())
# Out:
# Is key 2 present: True

# %%
print("is 9.2 present in values:",9.2 in cgpa.values())
# Out:
# is 9.2 present in values: False

# %% [markdown]
# merging dictionary

# %%
cgpa={1:8.9,2:5.2,3:8,4:9.1}
cgpa1={4:6.7,7:9.1,8:5.3}
print("cgpa:",cgpa)
print("cgpa1:",cgpa1)
cgpa1.update(cgpa)
print("cgpa1 after update:",cgpa1)
print("cgpa after update:",cgpa)
# Out:
# cgpa: {1: 8.9, 2: 5.2, 3: 8, 4: 9.1}
# cgpa1: {4: 6.7, 7: 9.1, 8: 5.3}
# cgpa1 after update: {4: 9.1, 7: 9.1, 8: 5.3, 1: 8.9, 2: 5.2, 3: 8}
# cgpa after update: {1: 8.9, 2: 5.2, 3: 8, 4: 9.1}

# %%
list1=[30,40,50,60]
list2=[50,60,70,80]
sum=(list1+list2)
print(sum)
# Out:
# [30, 40, 50, 60, 50, 60, 70, 80]

# %%
cars={"brand":"ford","model":"mustang","year":"1964"}
print(cars.items())
# Out:
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', '1964')])

# %%
cars["color"]="red"
print("after adding color red:",cars)
# Out:
# after adding color red: {'brand': 'ford', 'model': 'mustang', 'year': '1964', 'color': 'red'}

# %%
print(cars.keys())
print(cars.values())
print(cars.items())
# Out:
# dict_keys(['brand', 'model', 'year', 'color'])
# dict_values(['ford', 'mustang', '1964', 'red'])
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', '1964'), ('color', 'red')])

# %%
print("is model present:","model" in cars.keys())
# Out:
# is model present: True

# %%
keys=["movie","hero","release year"]
values=["kantara","Rishabh",2022]
create_dict=dict(zip(keys,values))
print(create_dict)
# Out:
# {'movie': 'kantara', 'hero': 'Rishabh', 'release year': 2022}

# %%
keys=["movie","hero","release year"]
values=["kantara","Rishabh",2022]
for i in range(len(keys)):
    create_dict[keys[i]]=values[i]
print(create_dict)
# Out:
# {'movie': 'kantara', 'hero': 'Rishabh', 'release year': 2022}

# %% [markdown]
# copying from onr dict to another

# %%
dict1={"name":"john",10:[2,4,3]}
dict2=dict1.copy()
print(dict1)
print(dict2)
print()
print("after change")
print()
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'name': 'john', 10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
#
# after change
#
# {'name': 'john'}
# {'name': 'john', 10: [2, 4, 3]}

# %%
dict1={"name":"john",10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print()
print("after change")
print()
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'name': 'john', 10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
#
# after change
#
# {'name': 'john'}
# {'name': 'john'}

# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
    squares.append(n**2)
