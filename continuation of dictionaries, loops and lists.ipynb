# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
    squares.append(n**2)
print(nums)
print(squares)
# Out:
# [1, 2, 3, 4]
# [1, 4, 9, 16]

# %%
lst=[1,2,3]
for x in lst:
    lst.append(x)
    if len(lst)>4:
        break
    print(lst)
# Out:
# [1, 2, 3, 1]

# %%
crops=['rice' ,'wheat','maize']
yield_values=[120,85,60]
crop_yield=dict(zip(crops,yield_values))
print(crop_yield)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60}

# %%
print(len(keys))
# Out:
# 3

# %%
print("yield of wheat is:",crop_yield['wheat'])
# Out:
# yield of wheat is: 85

# %%
crop_yield['pulses']=45
print("after adding pulses:",crop_yield)
# Out:
# after adding pulses: {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
crop_yield.update({'rice':130})
print("after update:",crop_yield)
# Out:
# after update: {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
croplist=list(crop_yield.keys())
print("the crops grown are:",croplist)
# Out:
# the crops grown are: ['rice', 'wheat', 'maize', 'pulses']

# %%
yieldlist=list(crop_yield.values())
print("the yield of crops are:",yieldlist)
# Out:
# the yield of crops are: [130, 85, 60, 45]

# %%
print("Is sugarcane cultivated:",'sugarcane' in crop_yield)
# Out:
# Is sugarcane cultivated: False

# %%
crop_yield['wheat']=int((crop_yield['wheat']+10))
print(crop_yield)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
print("total yield of all crops:",sum(yield_values))
# Out:
# total yield of all crops: 330

# %%
for keys,values in crop_yield.items():
    print(keys,":",values)
# Out:
# rice : 130
# wheat : 95
# maize : 60
# pulses : 45

# %%
crop_yield2=crop_yield.copy()
print("new dictionary:",crop_yield2)
print("the values of new dictionary:",crop_yield2.values())
# Out:
# new dictionary: {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
# the values of new dictionary: dict_values([130, 95, 60, 45])

# %%
crop_yield2.clear()
print(crop_yield2)
# Out:
# {}

# %%
del crop_yield2
print(crop_yield2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 2
#       1 del crop_yield2
# ----> 2 print(crop_yield2)
#
# NameError: name 'crop_yield2' is not defined

# %%
print("yield of jowar:",crop_yield["jowar"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 print("yield of jowar:",crop_yield["jowar"])
#
# KeyError: 'jowar'

# %%
print("yield of jowar:",crop_yield.get("jowar",'not cultivated'))
# Out:
# yield of jowar: not cultivated

# %%
if "jowar" in crop_yield :
    print("jowar is cultivated")
else:
    print("jowar is not cultivated")
# Out:
# jowar is not cultivated
